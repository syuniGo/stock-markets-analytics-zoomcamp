# %% [markdown]
# <a href="https://colab.research.google.com/github/syuniGo/stock-markets-analytics-zoomcamp/blob/main/01_intro_and_data_sources.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# install main library YFinance
# !pip install yfinance

# %%
# IMPORTS
import numpy as np
import pandas as pd

#Fin Data Sources
import yfinance as yf
import pandas_datareader as pdr

#Data viz
import plotly.graph_objs as go
import plotly.express as px

import time
from datetime import date

# %%
end = date.today()
print(f'Year = {end.year}; month= {end.month}; day={end.day}')

start = date(year=end.year-70, month=end.month, day=end.day)
print(f'Period for indexes: {start} to {end} ')
# Out:
# Year = 2024; month= 4; day=21
# Period for indexes: 1954-04-21 to 2024-04-21

# %%
# Real Potential Gross Domestic Product (GDPPOT), Billions of Chained 2012 Dollars, QUARTERLY
# https://fred.stlouisfed.org/series/GDPC1)
gdppot = pdr.DataReader("GDPC1", "fred", start=start)

# %%
gdppot
# Out:
#                 GDPC1
# DATE
# 1954-07-01   2880.482
# 1954-10-01   2936.852
# 1955-01-01   3020.746
# 1955-04-01   3069.910
# 1955-07-01   3111.379
# ...               ...
# 2022-10-01  21989.981
# 2023-01-01  22112.329
# 2023-04-01  22225.350
# 2023-07-01  22490.692
# 2023-10-01  22679.255
#
# [278 rows x 1 columns]

# %%
gdppot['gdppot_us_yoy'] = gdppot.GDPC1/gdppot.GDPC1.shift(4)-1
# gdppot['gdppot_us_qoq'] = gdppot.GDPC1/gdppot.GDPC1.shift(4)-1
# df_high_growth = gdppot[gdppot['gdppot_us_yoy'] > 0.02]
# df_high_growth

# %%
gdppot.columns
# Out:
# Index(['GDPC1', 'gdppot_us_yoy'], dtype='object')

# %%
gdppot['2023-01':'2023-12']
# Out:
#                 GDPC1  gdppot_us_yoy
# DATE
# 2023-01-01  22112.329       0.017179
# 2023-04-01  22225.350       0.023825
# 2023-07-01  22490.692       0.029269
# 2023-10-01  22679.255       0.031345

# %%
import math
mean_value = gdppot[gdppot.index.year == 2023]["gdppot_us_yoy"].mean()
print(mean_value)
mean_percent = mean_value * 100
print(mean_percent)
rounded_mean_percent = round(mean_percent,1)
mean_percent
# rounded_mean = math.ceil(mean_value * 10) / 10
# rounded_mean
rounded_mean_percent
# Out:
# 0.02540443392867625
# 2.5404433928676253
# 2.5

# %%
dgs2 = pdr.DataReader("DGS2", "fred", start='2000-01-01')
dgs2.tail(5)
# Out:
#             DGS2
# DATE
# 2024-04-12  4.88
# 2024-04-15  4.93
# 2024-04-16  4.97
# 2024-04-17  4.93
# 2024-04-18  4.98

# %%
dgs10 = pdr.DataReader("DGS10", "fred", start='2000-01-01')

# %% [markdown]
# gdppot['GDPPOT']*斜体文本*

# %%
dgs = dgs2.join(dgs10)
dgs['diff'] = dgs.DGS10 - dgs.DGS2
dgs_min = dgs['diff'].min()
dgs_mins =  round(dgs_min,1)
dgs_mins
# Out:
# -1.1

# %%
cpilfesl = pdr.DataReader("CPILFESL", "fred", start=start)

# %%
cpilfesl['cpi_core_yoy'] = cpilfesl.CPILFESL/cpilfesl.CPILFESL.shift(12)-1
cpilfesl['cpi_core_mom'] = cpilfesl.CPILFESL/cpilfesl.CPILFESL.shift(1)-1

cpilfesl.tail(13)
# Out:
#             CPILFESL  cpi_core_yoy  cpi_core_mom
# DATE
# 2023-03-01   305.112      0.055601      0.003249
# 2023-04-01   306.539      0.055157      0.004677
# 2023-05-01   307.646      0.053322      0.003611
# 2023-06-01   308.245      0.048552      0.001947
# 2023-07-01   308.945      0.047076      0.002271
# 2023-08-01   309.656      0.044128      0.002301
# 2023-09-01   310.644      0.041437      0.003191
# 2023-10-01   311.390      0.040217      0.002401
# 2023-11-01   312.349      0.040151      0.003080
# 2023-12-01   313.209      0.039101      0.002753
# 2024-01-01   314.438      0.038747      0.003924
# 2024-02-01   315.565      0.037620      0.003584
# 2024-03-01   316.698      0.037973      0.003590

# %%
sp500 = yf.download(tickers = "^GSPC",period = "max",interval = "1d")
spstart = sp500.loc['2019-04-09']
spend = sp500.loc['2024-04-09']
sp500
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 1927-12-30    17.660000    17.660000    17.660000    17.660000    17.660000
# 1928-01-03    17.760000    17.760000    17.760000    17.760000    17.760000
# 1928-01-04    17.719999    17.719999    17.719999    17.719999    17.719999
# 1928-01-05    17.549999    17.549999    17.549999    17.549999    17.549999
# 1928-01-06    17.660000    17.660000    17.660000    17.660000    17.660000
# ...                 ...          ...          ...          ...          ...
# 2024-04-15  5149.669922  5168.430176  5052.470215  5061.819824  5061.819824
# 2024-04-16  5064.589844  5079.839844  5039.830078  5051.410156  5051.410156
# 2024-04-17  5068.970215  5077.959961  5007.250000  5022.209961  5022.209961
# 2024-04-18  5031.520020  5056.660156  5001.890137  5011.120117  5011.120117
# ...

# %%
increase1 =(spend['Close']-spstart['Close'])/spstart['Close']
round(increase1,2)*100
# Out:
# 2878.199951171875

# %%
Mexico = yf.download(tickers = "^MXX",period = "max",interval = "1d")
Mexicostart = Mexico.loc['2019-04-09']
Mexicoend = Mexico.loc['2024-04-09':'2024-04-09']
increase2 =(Mexicoend['Close']-Mexicostart['Close'])/Mexicostart['Close']
math.ceil(increase2*100*100)/100
# Out:
# [*********************100%%**********************]  1 of 1 completed
# <ipython-input-121-f331b71d0b83>:5: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   math.ceil(increase2*100*100)/100
# 27.51

# %%
SR2222 = yf.download(tickers ="2222.SR",start="2023-01-01",end="2023-12-31",interval = "1d")
BRKB = yf.download(tickers ="BRK-B",start="2023-01-01",end="2023-12-31",interval = "1d")
AAPL = yf.download(tickers ="AAPL",start="2023-01-01",end="2023-12-31",interval = "1d")
MSFT = yf.download(tickers ="MSFT",start="2023-01-01",end="2023-12-31",interval = "1d")
GOOG = yf.download(tickers ="GOOG",start="2023-01-01",end="2023-12-31",interval = "1d")
JPM = yf.download(tickers ="JPM",start="2023-01-01",end="2023-12-31",interval = "1d")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
JPM
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-03  135.240005  136.740005  133.889999  135.119995  129.648499
# 2023-01-04  135.990005  137.679993  135.570007  136.380005  130.857483
# 2023-01-05  135.660004  135.710007  133.699997  135.350006  130.828476
# 2023-01-06  136.130005  138.380005  134.490005  137.940002  133.331970
# 2023-01-09  138.600006  138.880005  136.880005  137.369995  132.780991
# ...                ...         ...         ...         ...         ...
# 2023-12-22  167.500000  168.229996  167.229996  167.399994  165.409210
# 2023-12-26  167.460007  168.770004  167.179993  168.389999  166.387451
# 2023-12-27  167.839996  169.470001  167.580002  169.399994  167.385437
# 2023-12-28  169.350006  170.660004  169.000000  170.300003  168.274750
# 2023-12-29  170.000000  170.690002  169.630005  170.100006  168.077133
#
#               Volume
# Date
# 2023-01-03  11054800
# 2023-01-04  11687600
# 2023-01-05   8381300
# ...

# %%
import inspect

def calRange(df):
  frame = inspect.currentframe()
  print(len(inspect.getargvalues(frame)))
  args, _,_, values = inspect.getargvalues(frame)
  # print('function name "%s"' % inspect.getframeinfo(frame)[0])
  # for i in args:
  #   print('    %s = %s' % (i, values[i]))
  max =df['Close'].max()
  print(max)
  min =df['Close'].min()
  res = (max - min )/max
  print(res)
  re = math.ceil(res*100*100)/100
  print(f'+{re}%')
  return re

# %%
calRange(SR2222)
calRange(BRKB)
calRange(AAPL)
calRange(MSFT)
calRange(GOOG)
calRange(JPM)
# Out:
# 4
# 35.04999923706055
# 0.19725070789572696
# +19.73%
# 4
# 370.4800109863281
# 0.20775750091289963
# +20.78%
# 4
# 198.11000061035156
# 0.36893646833629906
# +36.9%
# 4
# 382.70001220703125
# 0.419101148503937
# +41.92%
# 4
# 142.82000732421875
# 0.3924520921912013
# +39.25%
# 4
# 170.3000030517578
# 0.2665296451923929
# +26.66%
# 26.66

# %%
import inspect

def my_function(arg1, arg2):
    frame = inspect.currentframe()
    args, _, _, values = inspect.getargvalues(frame)
    print('function name "%s"' % inspect.getframeinfo(frame)[2])
    for i in args:
        print('    %s = %s' % (i, values[i]))

my_function("Hello", "World")
# Out:
# function name "my_function"
#     arg1 = Hello
#     arg2 = World

# %%
import yfinance as yf

msft = yf.Ticker("2222.sr")
msft.info
hist = msft.history(start="2023-01-01",end="2023-12-31")
# msft.get_actions()
msft.history_metadata
msft
# Out:
# yfinance.Ticker object <2222.SR>

# %%
msft.get_actions()
# Out:
#                            Dividends  Stock Splits
# Date
# 2023-03-15 00:00:00+03:00   0.302364           0.0
# 2023-05-09 00:00:00+03:00   0.000000           1.1
# 2023-05-17 00:00:00+03:00   0.302400           0.0
# 2023-09-11 00:00:00+03:00   0.153000           0.0
# 2023-11-15 00:00:00+03:00   0.153000           0.0

# %%
def caldividends(df):
  stock = yf.Ticker(df)
  hist = stock.history(start="2023-01-01",end="2023-12-31")
  # print(hist.info)
  sum = hist['Dividends'].sum()
  last_p = hist.iloc[-1]['Close']
  dividendYield = sum/last_p
  re = math.ceil(dividendYield*100*10)/10

  print('re',re)
  return re

# %%
caldividends('2222.SR')
caldividends('BRK-B')
caldividends('AAPL')
caldividends('MSFT')
caldividends('GOOG')
caldividends('JPM')
# Out:
# re 2.8
# re 0.0
# re 0.5
# re 0.8
# re 0.0
# re 2.5
# 2.5
